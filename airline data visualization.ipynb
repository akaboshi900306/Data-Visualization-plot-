# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
#ir.columns= ['year','month','carrier','carrier_name',"airport","airport_name","arr_flights","arr_del15","carrier_ct","weather_ct","nas_ct","secu

sns.set()

# %%
atl = air.loc[(air["airport"]=="ATL")|(air["airport"]=="BOS")]
#bos = air.loc[air["airport"]=="BOS"]
airport =atl[["year","airport","arr_flights","arr_del15"]]
#airport2=bos[["year","airport","arr_flights","arr_del15"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-31feb8cecb85> in <module>()
# ----> 1 atl = air.loc[(air["airport"]=="ATL")|(air["airport"]=="BOS")]
#       2 #bos = air.loc[air["airport"]=="BOS"]
#       3 airport =atl[["year","airport","arr_flights","arr_del15"]]
#       4 #airport2=bos[["year","airport","arr_flights","arr_del15"]]
#
# NameError: name 'air' is not defined

# %%
air = pd.read_csv("C:/Users/akabo/Downloads/data visualization/AirlineDelayData2003-2017.csv",header= 0)
air.head()
#air.columns= ['year','month','carrier','carrier_name',"airport","airport_name","arr_flights","arr_del15","carrier_ct","weather_ct","nas_ct","security_ct","late_aircraft_ct","arr_cancelled",'arr_diverted',"arr_delay", "carrier_delay","weather_delay","nas_delay","security_delay","late_aircraft_delay"]

# %%
atl
# Out:
#         year  month carrier                  carrier_name airport  \
# 2       2003      6      AA        American Airlines Inc.     ATL
# 7       2003      6      AA        American Airlines Inc.     BOS
# 93      2003      6      AS          Alaska Airlines Inc.     BOS
# 133     2003      6      B6               JetBlue Airways     ATL
# 157     2003      6      CO    Continental Air Lines Inc.     ATL
# 162     2003      6      CO    Continental Air Lines Inc.     BOS
# 252     2003      6      DH       Atlantic Coast Airlines     BOS
# 324     2003      6      DL          Delta Air Lines Inc.     ATL
# 331     2003      6      DL          Delta Air Lines Inc.     BOS
# 430     2003      6      EV   Atlantic Southeast Airlines     ATL
# 434     2003      6      EV   Atlantic Southeast Airlines     BOS
# 523     2003      6      FL   AirTran Airways Corporation     ATL
# 525     2003      6      FL   AirTran Airways Corporation     BOS
# ...

# %%
atl
a = airport.groupby(['airport', 'year']).sum().reset_index()

# %%
a
# Out:
#               arr_flights  arr_del15
# airport year
# ATL     2003     215951.0    42141.0
#         2004     416989.0   103842.0
#         2005     429800.0   105351.0
#         2006     404829.0   105673.0
#         2007     413867.0    96952.0
#         2008     414521.0    93706.0
#         2009     419208.0   107439.0
#         2010     414596.0    77891.0
#         2011     393051.0    69197.0
#         2012     391953.0    56370.0
#         2013     398882.0    72292.0
#         2014     369842.0    62396.0
#         2015     379498.0    55176.0
#         2016     384252.0    49607.0
#         2017     185478.0    28000.0
# BOS     2003      67886.0    11655.0
#         2004     132366.0    25771.0
#         2005     127993.0    30871.0
#         2006     131030.0    33535.0
#         2007     128388.0    34466.0
#         2008     117944.0    27634.0
#         2009     110763.0    23125.0
#         2010     113523.0    23700.0
#         2011     109693.0    25158.0
# ...

# %%
p=sns.stripplot(x="arr_del15", y="arr_flights",hue="airport",data=a)
#p.set(xticks=[10000,45000,5000],yticks=[0,45000,50000])
plt.setp(p,xticks=[1,7,10])

# %%
sns.set_style("whitegrid")

# %%
 pic1 =sns.pointplot(x="year", y="arr_flights",hue="airport",data=a,palette={"ATL":"g",
 "BOS":"m"},
 markers=["o","o"],
 linestyles=["-","--"])
 sns.pointplot(x="year", y="arr_del15",hue="airport",data=a,palette={"ATL":"g",
 "BOS":"m"},
 markers=["x","x"],
 linestyles=["-","--"])  
pic1.set_xticklabels(pic1.get_xticklabels(),rotation=30)
 #sns.pointplot(x="", y="arr_flights",data=a,color="blue")
 #plt.xlim(1,14)

plt.ylabel("numbers")
plt.title(' Total numbers of flights and delays in ATL and BOS from 2003 to 2017\n o stands for the flight and x stands for the delay')

plt.show()

# %%
for ax in g.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-185-dd858ad66d81> in <module>()
#       1
# ----> 2 for ax in g.axes.flat:
#       3     plt.setp(ax.get_xticklabels(), rotation=45)
#
# NameError: name 'g' is not defined
